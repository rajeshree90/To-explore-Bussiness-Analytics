# %% [markdown]
# # In this task we will perform 'Exploratory Data Analysis' on the provided dataset 'SampleSuperstore'.
# As a Business manager, here we will try to find out the weak areas where you can work to make more profit.

# %%
# Importing all libraries required in this notebook
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
import plotly
import seaborn as sns
# %matplotlib inline

# %%
store_data = pd.read_csv("SampleSuperstore.csv")
print("Data imported successfully")

store_data
# Out:
# Data imported successfully
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
store_data.iloc[10]
# Out:
# Ship Mode       Standard Class
# Segment               Consumer
# Country          United States
# City               Los Angeles
# State               California
# Postal Code              90032
# Region                    West
# Category             Furniture
# Sub-Category            Tables
# Sales                  1706.18
# Quantity                     9
# Discount                   0.2
# Profit                 85.3092
# Name: 10, dtype: object

# %%
store_data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
store_data.hist(figsize=(12,17),bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002D92CE25BC8>,
# ...
#       dtype=object)

# %%
store_data.plot()

# %%
store_data.mean()
# Out:
# Postal Code    55190.379428
# Sales            229.858001
# Quantity           3.789574
# Discount           0.156203
# Profit            28.656896
# dtype: float64

# %%
sns.heatmap(store_data.corr(),annot=True)

# %%
store_data.corr().plot.bar()

# %%
sns.countplot(x="Category",data=store_data).set_title("Most sold product line")
# Out:
# Text(0.5, 1.0, 'Most sold product line')

# %%
sns.countplot(x="Sub-Category",data=store_data).set_title("Most sold Sub-Category")
# Out:
# Text(0.5, 1.0, 'Most sold Sub-Category')

# %%
plt.xticks(rotation=270)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text xticklabel objects>)

# %%
plt.scatter(x=store_data['Sales'],y=store_data['Profit'])
plt.xlabel("Total sales")
plt.ylabel("Profit")
plt.show()

# %%
sns.set_style('ticks')
sns.countplot(x="Region",data=store_data,palette='hls')

# %%
sns.countplot(x="Region",hue='Category',data=store_data,palette='Accent')
